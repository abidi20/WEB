# %% [markdown]
# <a href="https://colab.research.google.com/github/abidi20/WEB/blob/main/Text_Augmentation_Using_NLPAUG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1- Install the nlpaug package**

# %%
pip install nlpaug
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 29.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2aa811bc-bdb7-4887-bda7-1d3873f8e817" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2aa811bc-bdb7-4887-bda7-1d3873f8e817">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# %cd /content/drive/MyDrive/from_Kaggle
# Out:
# /content/drive/MyDrive/from_Kaggle

# %% [markdown]
# ## **2-Import the different types of augmentation from the nlpaug package**

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as nafc

from nlpaug.util import Action

# %% [markdown]
# ## **3-Display the text**

# %%
text = 'The quick brown fox jumps over the lazy dog .'
print(text)
# Out:
# The quick brown fox jumps over the lazy dog .

# %% [markdown]
# ## **Character Augmenter**

# %% [markdown]
# **OCR Augmenter**
#
# Substitute character by pre-defined OCR error

# %%
aug = nac.OcrAug()
augmented_texts = aug.augment(text, n=3)
print("Original:")
print(text)
print("Augmented Texts:")
print(augmented_texts)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Texts:
# ['The quick brown fox jomp8 over the 1a2y dog.', 'The quick brown fox jomp8 over the lazy dog.', 'The qoicr 6kown fox jumps over the lazy dog.']

# %% [markdown]
# **Keyboard Augmenter**
#
# Substitute character by keyboard distance

# %%
aug = nac.KeyboardAug()
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The quick brodJ fox j&mpW ocet the lazy dog.']

# %% [markdown]
# **Random Augmenter**
#
# Insert character randomly

# %%
aug = nac.RandomCharAug(action="insert")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The wquwick brown fox j^um1ps ov7eAr the lazy dog.']

# %% [markdown]
# Substitute character randomly

# %%
aug = nac.RandomCharAug(action="substitute")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The quick Uro0n fox jImp) uv2r the lazy dog.']

# %% [markdown]
# Swap character randomly

# %%
aug = nac.RandomCharAug(action="swap")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The quick brown fox mjups vore the lazy dog.']

# %% [markdown]
# Delete character randomly

# %%
aug = nac.RandomCharAug(action="delete")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The qic ron fox jumps over the az dog.']

# %% [markdown]
# ## **Word Augmenter**
#
# # Spelling Augmenter
#
# Substitute word by spelling mistake words dictionary

# %%
aug = naw.SpellingAug()
augmented_texts = aug.augment(text, n=3)
print("Original:")
print(text)
print("Augmented Texts:")
print(augmented_texts)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Texts:
# ['Thes qchick brown fox jumps over the lszy dog.', 'Them quikly beown fox jumps over the lazy dog.', 'Thte quick brown fox jumps over the lszy dadg.']

# %%
aug = naw.SpellingAug()
augmented_texts = aug.augment(text, n=3)
print("Original:")
print(text)
print("Augmented Texts:")
print(augmented_texts)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Texts:
# ['Tho quick brown fox jumps ower hte lazy dog.', 'There quick broun fox jumps over dth lazy dog.', 'The qchick brwan fox jumps over the lazy gog.']

# %% [markdown]
# # **4- Word Embeddings Augmenter**
#
# > Ajouter une citation
#
#
#
# Insert word randomly by word embeddings similarity

# %%
pip install gensim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 85.4 MB/s eta 0:00:00
# ...

# %%
# !pip install nlpaug gensim --quiet

# %%
import nlpaug.augmenter.word as naw
from gensim.models import KeyedVectors

# %%
import os
print(os.path.exists('/content/drive/MyDrive/from_Kaggle/GoogleNews-vectors-negative300.bin.gz'))
# Out:
# True

# %%
# model_type: word2vec, glove or fasttext

from gensim.models import KeyedVectors
import gensim.models.keyedvectors as kv
import nlpaug.model.word_embs.word2vec as nlp_word2vec
nlp_word2vec.KeyedVectors = kv.KeyedVectors
model_path = '/content/drive/MyDrive/from_Kaggle/GoogleNews-vectors-negative300.bin.gz'


aug = naw.WordEmbsAug(
    model_type='word2vec', model_path='/content/drive/MyDrive/from_Kaggle/GoogleNews-vectors-negative300.bin.gz',
    action="insert")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The Shenmu quick brown Durantula fox jumps defeated over the lazy dog.']

# %% [markdown]
# Substitute word by word2vec similarity

# %%
# model_type: word2vec, glove or fasttextfrom gensim.models import KeyedVectors
from gensim.models import KeyedVectors


aug = naw.WordEmbsAug(
    model_type='word2vec', model_path='/content/drive/MyDrive/from_Kaggle/GoogleNews-vectors-negative300.bin.gz',
    action="insert")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The Alexander quick brown Lady fox jumps femi over the lazy dog.']

# %%
# model_type: word2vec, glove or fasttext
aug = naw.WordEmbsAug(
    model_type='word2vec', model_path='/content/drive/MyDrive/from_Kaggle/GoogleNews-vectors-negative300.bin.gz',
    action="substitute")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The quick reddy_brown fox dives duringthe the lazy dog.']

# %% [markdown]
# # **5- Contextual Word Embeddings Augmenter**
#
# Insert word by contextual word embeddings (BERT, DistilBERT, RoBERTA or XLNet)

# %%
aug = naw.ContextualWordEmbsAug(
    model_path='bert-base-uncased', action="insert")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# ...

# %% [markdown]
# Substitute word by contextual word embeddings (BERT, DistilBERT, RoBERTA or XLNet)

# %%
aug = naw.ContextualWordEmbsAug(
    model_path='bert-base-uncased', action="substitute")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['the quick brown cat jumps over the frozen brook.']

# %%
aug = naw.ContextualWordEmbsAug(
    model_path='distilbert-base-uncased', action="substitute")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
aug = naw.ContextualWordEmbsAug(
    model_path='roberta-base', action="substitute")
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# ...

# %% [markdown]
# # **Synonym Augmenter**
#
# Substitute word by WordNet's synonym

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
aug = naw.SynonymAug(aug_src='wordnet')
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The ready brown university fox leap over the lazy dog.']

# %% [markdown]
# ## **6- Continue here to use the ppdb Model**
#
#
# Substitute word by PPDB's synonym

# %%
aug = naw.SynonymAug(aug_src='ppdb', model_path='/content/drive/MyDrive/from_Kaggle/ppdb-2.0-s-all')
augmented_text = aug.augment(text)
print("Original:")
print(text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# The quick brown fox jumps over the lazy dog .
# Augmented Text:
# ['The rapid brown fox climbs over the lazy dog.']

# %% [markdown]
# Antonym Augmenter

# %%
aug = naw.AntonymAug()
_text = 'Good boy'
augmented_text = aug.augment(_text)
print("Original:")
print(_text)
print("Augmented Text:")
print(augmented_text)
# Out:
# Original:
# Good boy
# Augmented Text:
# ['Evil boy']
